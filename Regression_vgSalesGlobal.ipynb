# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = [10,5]

# %%
#ignore warnings

import warnings

#set the warning filter to ignore FutureWarning
warnings.simplefilter(action = "ignore" , category = FutureWarning)

# %%
df = pd.read_csv("/content/vgsalesGlobale.csv", index_col = "Name")

# %%
df.head(5)
# Out:
#                           Rank    Year  NA_Sales  EU_Sales  JP_Sales  \
# Name
# Wii Sports                   1  2006.0     41.49     29.02      3.77
# Super Mario Bros.            2  1985.0     29.08      3.58      6.81
# Mario Kart Wii               3  2008.0     15.85     12.88      3.79
# Wii Sports Resort            4  2009.0     15.75     11.01      3.28
# Pokemon Red/Pokemon Blue     5  1996.0     11.27      8.89     10.22
#
#                           Other_Sales  Global_Sales  Adventure  Fighting  \
# Name
# Wii Sports                       8.46         82.74          0         0
# Super Mario Bros.                0.77         40.24          0         0
# Mario Kart Wii                   3.31         35.82          0         0
# Wii Sports Resort                2.96         33.00          0         0
# Pokemon Red/Pokemon Blue         1.00         31.37          0         0
#
#                           Misc  ...  Zushi Games  bitComposer Games  \
# ...

# %%
df.tail(10)
# Out:
#                                                      Rank Platform    Year  \
# Name
# Mega Brain Boost                                    16591       DS  2008.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
# Eiyuu Densetsu: Sora no Kiseki Material Collect...  16593      PSP  2007.0
# Myst IV: Revelation                                 16594       PC  2004.0
# Plushees                                            16595       DS  2008.0
# Woody Woodpecker in Crazy Castle 5                  16596      GBA  2002.0
# Men in Black II: Alien Escape                       16597       GC  2003.0
# SCORE International Baja 1000: The Official Game    16598      PS2  2008.0
# Know How 2                                          16599       DS  2010.0
# Spirits & Spells                                    16600      GBA  2003.0
#
#                                                            Genre  \
# Name
# ...

# %%
df.shape
# Out:
# (16598, 10)

# %%
df.dtypes
# Out:
# Rank              int64
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, Wii Sports to Spirits & Spells
# Columns: 593 entries, Rank to responDESIGN
# dtypes: float64(6), int64(1), uint8(586)
# memory usage: 10.6+ MB

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df['Global_Sales'].describe()
# Out:
# count    16598.000000
# mean         0.537441
# std          1.555028
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ###Data on Specific Location

# %%
df.iloc[777]
# Out:
# Rank                             779
# Platform                         PS3
# Year                          2009.0
# Genre                        Shooter
# Publisher       Take-Two Interactive
# NA_Sales                         1.2
# EU_Sales                        0.62
# JP_Sales                         0.0
# Other_Sales                     0.29
# Global_Sales                    2.11
# Name: Borderlands, dtype: object

# %%
df.loc["Super Mario Bros."]
# Out:
#                    Rank Platform    Year     Genre Publisher  NA_Sales  \
# Name
# Super Mario Bros.     2      NES  1985.0  Platform  Nintendo     29.08
# Super Mario Bros.   201       GB  1999.0  Platform  Nintendo      3.40
#
#                    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Name
# Super Mario Bros.      3.58      6.81         0.77         40.24
# Super Mario Bros.      1.30      0.15         0.22          5.07

# %%
df.sort_values(by = "Year").head()
# Out:
#           Rank Platform    Year     Genre   Publisher  NA_Sales  EU_Sales  \
# Name
# Checkers  6898     2600  1980.0      Misc       Atari      0.22      0.01
# Boxing    2671     2600  1980.0  Fighting  Activision      0.72      0.04
# Freeway   5368     2600  1980.0    Action  Activision      0.32      0.02
# Defender  1971     2600  1980.0      Misc       Atari      0.99      0.05
# Kaboom!   1768     2600  1980.0      Misc  Activision      1.07      0.07
#
#           JP_Sales  Other_Sales  Global_Sales
# Name
# Checkers       0.0         0.00          0.24
# Boxing         0.0         0.01          0.77
# Freeway        0.0         0.00          0.34
# Defender       0.0         0.01          1.05
# Kaboom!        0.0         0.01          1.15

# %%
df.sort_values(by = "Year" , ascending =False ).head()
# Out:
#                                                    Rank Platform    Year  \
# Name
# Imagine: Makeup Artist                             5959       DS  2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV  2017.0
# Brothers Conflict: Precious Baby                  16441      PSV  2017.0
# Shin Megami Tensei IV: Final                       8295      3DS  2016.0
#
#                                                          Genre     Publisher  \
# Name
# Imagine: Makeup Artist                              Simulation       Ubisoft
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Brothers Conflict: Precious Baby                        Action  Idea Factory
# Shin Megami Tensei IV: Final                      Role-Playing   Deep Silver
#
# ...

# %%
df["Publisher"].head(10)
# Out:
# Name
# Wii Sports                   Nintendo
# Super Mario Bros.            Nintendo
# Mario Kart Wii               Nintendo
# Wii Sports Resort            Nintendo
# Pokemon Red/Pokemon Blue     Nintendo
# Tetris                       Nintendo
# New Super Mario Bros.        Nintendo
# Wii Play                     Nintendo
# New Super Mario Bros. Wii    Nintendo
# Duck Hunt                    Nintendo
# Name: Publisher, dtype: object

# %%
df[df["Genre"] == "Action"]
# Out:
#                                                      Rank Platform    Year  \
# Name
# Grand Theft Auto V                                     17      PS3  2013.0
# Grand Theft Auto: San Andreas                          18      PS2  2004.0
# Grand Theft Auto V                                     24     X360  2013.0
# Grand Theft Auto: Vice City                            25      PS2  2002.0
# Grand Theft Auto III                                   39      PS2  2001.0
# ...                                                   ...      ...     ...
# Original Frisbee Disc Sports: Ultimate & Golf       16567       DS  2007.0
# Fujiko F. Fujio Characters: Great Assembly! Sli...  16570      3DS  2014.0
# Planet Monsters                                     16585      GBA  2001.0
# Carmageddon 64                                      16586      N64  1999.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
#
#                                                      Genre  \
# ...

# %%
after_2015 =df["Year"] > 2015
df[after_2015]
# Out:
#                                                      Rank Platform    Year  \
# Name
# FIFA 17                                               222      PS4  2016.0
# Uncharted 4: A Thief's End                            272      PS4  2016.0
# Tom Clancy's The Division                             352      PS4  2016.0
# Far Cry: Primal                                       772      PS4  2016.0
# Tom Clancy's The Division                             847     XOne  2016.0
# ...                                                   ...      ...     ...
# Mighty No. 9                                        16565     XOne  2016.0
# Resident Evil 4 HD                                  16572     XOne  2016.0
# Farming 2017 - The Simulation                       16573      PS4  2016.0
# Rugby Challenge 3                                   16579     XOne  2016.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
#
# ...

# %% [markdown]
# ####The .quantile() method in Pandas is used to calculate the quantile values of a Series or DataFrame. A quantile represents a specific value below which a given fraction of the data falls. It provides a way to understand the distribution of numerical data by dividing it into intervals

# %%
Q1 = df['Year'].quantile(0.25)

# %%
Q3 = df['Year'].quantile(0.75)

# %%
IQR = Q3-Q1

# %%
print("The interquartile range is: ", IQR)
# Out:
# The interquartile range is:  7.0

# %% [markdown]
# ###Handling the missing data

# %%
df.isnull().sum()
# Out:
# Rank              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.dropna()
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %%
df.fillna(df.mean())
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %%
sns.histplot(df['Year'],kde =False)
plt.show()

# %%
sns.distplot(df['Other_Sales'], hist=False)
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.distplot(df["Rank"])
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.scatterplot(x = "Year" , y = "Global_Sales" , hue = "Rank" , data = df)
plt.show()

# %%
plt.figure(figsize = (8, 8))
sns.barplot(df)
plt.show()

# %%
plt.figure(figsize = ( 8, 8))
sns.stripplot(x="Genre" , y = "Rank", hue ='Genre', data = df)
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.boxplot(x = "Year" ,y = "Global_Sales" ,data = df)
plt.show()

# %%
sns.countplot(x = "Year", data =df , palette = "Blues")
plt.show()

# %% [markdown]
# ###Missing Data

# %%
sns.heatmap(df.isnull(),yticklabels= False ,cbar =False ,cmap = 'tab20c_r')
plt.title('Missing Data : Training set')
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(inplace =True)

# %%
df.drop('Platform', axis =1 ,inplace =True)

# %%
df.dtypes
# Out:
# Rank              int64
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# #Convert  onject into Category data type

# %%
objcat = ['Genre' , 'Publisher']

for colname in objcat:
  df[colname] = df[colname].astype('category')

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales     Adventure      Fighting          Misc  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean       0.048426      0.540910      0.078203      0.051317      0.103493
# ...

# %%
df.select_dtypes(['category']).columns
# Out:
# Index(['Genre', 'Publisher'], dtype='object')

# %%
#convert Categorical variable into 'dummy' or indicator variable

genre = pd.get_dummies(df['Genre'], drop_first = True) #drop_first prevents multi-collinearity
publisher = pd.get_dummies(df['Publisher'], drop_first = True)

# %%
df.head(2)
# Out:
#                    Rank    Year     Genre Publisher  NA_Sales  EU_Sales  \
# Name
# Wii Sports            1  2006.0    Sports  Nintendo     41.49     29.02
# Super Mario Bros.     2  1985.0  Platform  Nintendo     29.08      3.58
#
#                    JP_Sales  Other_Sales  Global_Sales
# Name
# Wii Sports             3.77         8.46         82.74
# Super Mario Bros.      6.81         0.77         40.24

# %%
#add new dummy columns to Data frame

df = pd.concat([df, genre ,publisher] , axis =1)
df.head(2)
# Out:
#                    Rank    Year     Genre Publisher  NA_Sales  EU_Sales  \
# Name
# Wii Sports            1  2006.0    Sports  Nintendo     41.49     29.02
# Super Mario Bros.     2  1985.0  Platform  Nintendo     29.08      3.58
#
#                    JP_Sales  Other_Sales  Global_Sales  Adventure  ...  \
# Name                                                               ...
# Wii Sports             3.77         8.46         82.74          0  ...
# Super Mario Bros.      6.81         0.77         40.24          0  ...
#
#                    Zushi Games  bitComposer Games  dramatic create  fonfun  \
# Name
# Wii Sports                   0                  0                0       0
# Super Mario Bros.            0                  0                0       0
#
#                    iWin  id Software  imageepoch Inc.  inXile Entertainment  \
# Name
# Wii Sports            0            0                0                     0
# ...

# %%
df.drop(['Genre' , 'Publisher'] ,axis =1 , inplace =True)

#Shape  of Train data

df.shape
# Out:
# (16291, 593)

# %%
df
# Out:
#                                                    Rank    Year  NA_Sales  \
# Name
# Wii Sports                                            1  2006.0     41.49
# Super Mario Bros.                                     2  1985.0     29.08
# Mario Kart Wii                                        3  2008.0     15.85
# Wii Sports Resort                                     4  2009.0     15.75
# Pokemon Red/Pokemon Blue                              5  1996.0     11.27
# ...                                                 ...     ...       ...
# Woody Woodpecker in Crazy Castle 5                16596  2002.0      0.01
# Men in Black II: Alien Escape                     16597  2003.0      0.01
# SCORE International Baja 1000: The Official Game  16598  2008.0      0.00
# Know How 2                                        16599  2010.0      0.00
# Spirits & Spells                                  16600  2003.0      0.01
#
#                                                   EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# #Model is ready for Training

# %%
# Split data to be used in the models
# Create matrix of features

x = df.drop('Global_Sales' ,axis = 1) #grab everything else but global_sales

#Create target variable

y = df['Global_Sales']

# %% [markdown]
# ##Use x and y variable to split training  data into train and test set

# %%
from sklearn.model_selection import  train_test_split
x_train, x_test, y_train ,y_test =train_test_split(x,y, test_size = .20 , random_state = 101)

# %%
df.shape
# Out:
# (16291, 593)

# %%
x_train.shape
# Out:
# (13032, 592)

# %%
x_train
# Out:
#                                             Rank    Year  NA_Sales  EU_Sales  \
# Name
# Psychic Force                               8664  1996.0      0.01      0.01
# Sherlock Holmes: The Mystery of the Mummy   4836  2009.0      0.06      0.30
# Commando                                    1793  1986.0      0.71      0.16
# Junior Classic Games                        4965  2009.0      0.26      0.09
# Black                                       1594  2006.0      1.01      0.04
# ...                                          ...     ...       ...       ...
# Kingdoms of Amalur: Reckoning               5788  2012.0      0.14      0.13
# Fireblade                                   8149  2002.0      0.09      0.07
# Metroid: Other M                            1376  2010.0      0.87      0.31
# .hack//Infection Part 1                     1565  2002.0      0.49      0.38
# Big Air Freestyle                          13389  2002.0      0.04      0.01
#
# ...

# %%
x_test.shape
# Out:
# (3259, 592)

# %%
x_test
# Out:
#                                                      Rank    Year  NA_Sales  \
# Name
# Supercar Street Challenge                            1820  2001.0      0.55
# Two Worlds II                                        7523  2011.0      0.09
# Mobile Suit Gundam: Mokuba no Kiseki                13862  2012.0      0.00
# Pirates of the Caribbean: Dead Man's Chest           4213  2006.0      0.33
# Hi! Hamtaro - Little Hamsters,big Adventures: H...  11942  2005.0      0.07
# ...                                                   ...     ...       ...
# Saint Seiya: Sanctuary Battle                        6978  2011.0      0.00
# OutRun 2006: Coast 2 Coast                          13111  2006.0      0.02
# Dragon Quest IV: Michibikareshi Monotachi            1660  2001.0      0.00
# FIFA Soccer 06                                      10048  2005.0      0.10
# Higurashi no Naku Koro ni Kizuna: Dai-Yon-Kan -...  14615  2010.0      0.00
#
# ...

# %%
from sklearn import preprocessing
pre_process = preprocessing.StandardScaler().fit(x)
x_transform = pre_process.fit_transform(x)

# %%
x_transform.shape
# Out:
# (16291, 592)

# %%
y.shape
# Out:
# (16291,)

# %% [markdown]
# ##Now the train data is perfect for a machine learning algorithm:
#
# all the data is numeric
#
# everything is concatenated together

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

#create intance of model

model = LinearRegression()

#pass training data into model

model.fit(x_train, y_train)

#pipe =make_pipeline(StandarScaler(),LinearRegression())
#pipe.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ###Model Testing

# %%
####prediction

# %%
y_pred = model.predict(x_test)

# %%
print(y_pred.shape)
print(y_pred)
# Out:
# (3259,)
# [1.1198979  0.20974566 0.0405723  ... 1.20963177 0.12072504 0.03023792]

# %% [markdown]
# ###Combine Actual and predicted value side by side

# %%
result = np.column_stack((y_test, y_pred))

print("-------------------------------")
#printing the result
print("Actual Value | predicted Values")
print("--------------------------------")

for actual, predicted in result:
  print(f"{actual :14.2f} | {predicted :12.2f}")
# Out:
# -------------------------------
# Actual Value | predicted Values
# --------------------------------
#           1.12 |         1.12
#           0.20 |         0.21
#           0.04 |         0.04
#           0.47 |         0.46
#           0.07 |         0.07
#           0.31 |         0.31
#           4.64 |         4.65
#           0.50 |         0.50
#           0.06 |         0.07
#           0.10 |         0.09
#           1.19 |         1.18
#           0.53 |         0.53
#           0.17 |         0.17
#           1.13 |         1.13
#           1.69 |         1.70
#           0.06 |         0.06
#           7.20 |         7.20
#           0.17 |         0.18
#           0.48 |         0.48
#           0.04 |         0.04
#           0.04 |         0.04
#           0.28 |         0.28
#           0.05 |         0.05
#           0.01 |         0.01
#           0.67 |         0.67
#           0.05 |         0.04
#           0.81 |         0.81
#           0.07 |         0.07
# ...

# %% [markdown]
# ##Residual Analysis
# Residual analysis in linear regression is a way to check how well the model fits the data. It involves looking at the differences (residuals) between the actual data points and the predictions from the model.

# %%
residual = actual- y_pred.reshape(-1)
print(residual)
# Out:
# [-1.08989790e+00 -1.79745656e-01 -1.05722956e-02 ... -1.17963177e+00
#  -9.07250411e-02 -2.37918149e-04]

# %%
sns.displot(residual, kde =True)

# %%
sns.scatterplot(x=y_test, y=y_pred, color='blue', label='Actual Data points')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Ideal Line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual (Linear Regression)')
plt.legend()
plt.show()

# %% [markdown]
# #Model evaluation

# %%
#mean_squared_error
from sklearn.metrics import mean_squared_error

print('Linear Regression Model')

#Result

print('--'*30)

#mean_sequared_error(y_test, y_pred)

mse = mean_squared_error(y_test,y_pred)

rmse = np.sqrt(mse)

#print("Evalution MEtrics")

print("Mean Squared Error:", mse)
print("Root Mean Squared Error: ",rmse)
# Out:
# Linear Regression Model
# ------------------------------------------------------------
# Mean Squared Error: 2.8412881049251674e-05
# Root Mean Squared Error:  0.0053303734436952604

# %% [markdown]
# #Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor


rf_regressor = DecisionTreeRegressor()
rf_regressor.fit(x_train,y_train)

#Predicting the SalePrices using test set
y_pred_rf = rf_regressor.predict(x_test)

DTr = mean_squared_error(y_pred_rf,y_test)
#Random Forest Regression Accuracy with test set
print('Decision Tree Regression : ',DTr)
# Out:
# Decision Tree Regression :  0.0012828168149739195

# %% [markdown]
# #Random Forest

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor()
rf_regressor.fit(x_train,y_train)

#Predicting the SalePrices using test set
y_pred_rf = rf_regressor.predict(x_test)
RFr = mean_squared_error(y_pred_rf,y_test)
#Random Forest Regression Accuracy with test set
print('Random Forest Regression : ',RFr)
# Out:
# Random Forest Regression :  0.0009237875329855793

# %% [markdown]
# #Gradient Boosting Regression

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

rf_regressor = GradientBoostingRegressor()
rf_regressor.fit(x_train,y_train)

#Predicting the SalePrices using test set
y_pred_rf = rf_regressor.predict(x_test)

#Random Forest Regression Accuracy with test set
GBr = mean_squared_error(y_pred_rf,y_test)
print('Gradient Boosting Regression : ',GBr)
# Out:
# Gradient Boosting Regression :  0.0010150194167834609

# %%
# Sample model scores (replace these with your actual model scores)
model_scores = {
    "Linear Regression":  2.8412881049251674e-05,
    "Descison Tree": 0.0012828168149739195,
    "Random Forest":0.0009237875329855793,
    "Gradient Boosting":  0.0010150194167834609
}

# Sort the model scores in ascending order based on their values (lower values first)
sorted_scores = sorted(model_scores.items(), key=lambda x: x[1])

# Display the ranking of the models
print("Model Rankings (lower values are better):")
for rank, (model_name, score) in enumerate(sorted_scores, start=1):
    print(f"{rank}. {model_name}: {score}")
# Out:
# Model Rankings (lower values are better):
# 1. Linear Regression: 2.8412881049251674e-05
# 2. Random Forest: 0.0009237875329855793
# 3. Gradient Boosting: 0.0010150194167834609
# 4. Descison Tree: 0.0012828168149739195
